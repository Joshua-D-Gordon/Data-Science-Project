# %%
#Q1

#A

#About 1/125 of births are non-identical twins and 1/300 of births are identical twins. Elvis had
#A twin brother who died in childbirth. What is the probability that Elvis had an identical twin? )
#It can be assumed that the probability
#For the birth of a son and a daughter equal to 1/2.)

#ANSWER
# The Probability of having a twin ( identical or non identical is 1/125 + 1/300 = 17/1500)

# Knowing that alvis was born with a twin we can say that the probabilty of alvis's twin being an identical twin +
# the probabilty of alvis's twin being an non identical twin is 100% as these are the only two senerios.

# therefor we shall normalize our eqausion of 1/125 + 1/300 = 17/1500 by multiplying both side by 1500 and dividing by 17.

# We come to 12/17 + 5/17 = 1.

#meaning in otherwords given there are twins there is a 12/17 = 70.58% chance they are non identical twins and
# a 5/17 = 29.41% chance they are identical twins.

# therefor as alvis was born with a twin there is a 29.41% chance that they were identical. the fact that alvis had a twin 
# brother satisfys this probability as if it were have been a twin sister we could say the probability is 0%.


#B

#There are two bowls of cookies. Bowl 1 has 10 almond cookies and 30 chocolate chip cookies. In bowl 2 there is
#20 almond cookies and 20 chocolate chip cookies. Eric chose a bowl at random and chose a cookie from it at random.
#The cookie selected is chocolate. What is the probability that Eric chose Bowl 1?

#ANSWER 

# Eric chose a random bowl meaning 50% chance of bowl 1 and 50% chance of bowl 2.

# We can say bowl 1 has a 75% chance of picking a choclate coockie as the are 30 / 40 choclate coockies in the bowl

# We can say bowl 2 has a 50% chance of picking a choclate coockie as the are 20 / 40 choclate coockies in the bowl

# the probability of chosing a choclate coockie fromeither bowl is therfore 0.5*0.75 + 0.5*0.5 = 3/8 + 2/8 = 5/8.

# given that eric has choose at random a choclate coockie we can say the probability of chosing a chochlate coockie from bowl one 
# + the probability of choosing a choclate coockie from bolw 2 is = 100%

# there for we can say 3/8 + 2/8 = 5/8 and we shall yet again normalize our eqausion:

# 3/5 + 2/5 = 1 meaning there is a 3/5 = 60% chance eric choose from bowl 1.

# %%
#Q2
'''
בשנת 1995 חברת M&M הוסיפה את הצבע כחול. לפני השנה הזו, התפלגות הצבעים
בשקית M&M נראית כך:
30% Brown, 20% Yellow, 20% Red, 10% Green, 10% Orange, 10%
Tan
החל משנת 1995 ,ההתפלגות נראית כך:
24% Blue , 20% Green, 16% Orange, 14% Yellow, 13% Red, 13% Brown.
לחבר שלכם יש 2 שקיות M&M ,אחת משנת 1994 ואחת משנת 1996 והוא לא מוכן לגלות לכם
איזו שקית שייכת לאיזו שנה. אבל הוא נותן לכם סוכריה אחת מכל שקית. סוכריה אחת היא צהובה ואחת
היא ירוקה. מה הסיכוי שהסוכריה הצהובה הגיעה מהשקית של 1994 ?
'''
#ANSWER

# We can say the probability o pulling a yellow M&M at random from the packet created before 1995 is 20%.
# We can also say the probability o pulling a yellow M&M at random from the packet created after 1995 is 14%.

#there for the probability of pulling a yellow at random is taking from the first bag (50% chance ) and pulling a yellow 
# + the pulling a yellow from the second bag (50% chance ). = 0.5*0.2 + 0.5*0.14 = 17/100.

# Our friend has pulled us a yellow meaing there are two senerios: he pulled it from the first bag or the second bag.
# this means we can normalize our eqausion: 0.5*0.2 + 0.5*0.14 = 17/100 = 1000/1700 + 700/1700  = 1.

# therefor the probability of the yellow being pulled by the first bag ( made before 1995) is 58.82%
# Out:
# '\nבשנת 1995 חברת M&M הוסיפה את הצבע כחול. לפני השנה הזו, התפלגות הצבעים\nבשקית M&M נראית כך:\n30% Brown, 20% Yellow, 20% Red, 10% Green, 10% Orange, 10%\nTan\nהחל משנת 1995 ,ההתפלגות נראית כך:\n24% Blue , 20% Green, 16% Orange, 14% Yellow, 13% Red, 13% Brown.\nלחבר שלכם יש 2 שקיות M&M ,אחת משנת 1994 ואחת משנת 1996 והוא לא מוכן לגלות לכם\nאיזו שקית שייכת לאיזו שנה. אבל הוא נותן לכם סוכריה אחת מכל שקית. סוכריה אחת היא צהובה ואחת\nהיא ירוקה. מה הסיכוי שהסוכריה הצהובה הגיעה מהשקית של 1994 ?\n'

# %%
#Q3

'''
 .הלכת לדוקטור בעקבות ציפורן חודרנית. הדוקטור בחר בך באקראי לבצע בדיקת דם הבודקת
שפעת חזירים. ידוע סטטיסטית ששפעת זו פוגעת ב -1 מתוך 000,10 אנשים באוכלוסייה. הבדיקה
מדויקת ב -99 אחוז במובן שההסתברות ל positive false היא %1 .הווה אומר שהבדיקה סיווגה
בטעות אדם בריא כאדם חולה היא 1 אחוז. ההסתברות ל - negative false היא 0 – אין סיכוי
שהבדיקה תגיד על אדם החולה בשפעת חזירים שהוא בריא. בבדיקה יצאת חיובי )יש לך שפעת(.
א. מה ההסתברות שיש לך שפעת חזירים?

ב. נניח שחזרת מתאילנד לאחרונה ואתה יודע ש-1 מתוך 200 אנשים שחזרו לאחרונה מתאילנד,
חזרו עם שפעת חזירים. בהינתן אותה סיטואציה כמו בשאלה א, מה ההסתברות )המתוקנת(
שיש לך שפעת חזירים? 
'''

#ANSWER

#A

#We know the false positive rate is 1% and the false negitiave rate is 0%.
#we shall use bayes law that states the following:
# p(a/b)  = (p(a)p(a/b))/(p(a)p(a/b) + p(a')p(b/a))
# == 0.0001*1/(0.0001*1+ 0.9999*0.01) == 0.0001/0.010099 == 100/10099 % chanceof me being actually positive when testing positive

#B

# We shall use the same formula however this time our p(a) is 1/200 and not 1/10,000
# p(a/b)  = (p(a)p(a/b))/(p(a)p(a/b) + p(a')p(b/a))
# == (1/200*1)/(1/200*1 + 199/200*0.01) == (1/200)/(299/20,000) == 0.3344 meaning there is a a 33.44% chance i have swin flu 
# when coming back from tailand

# %%
#Random varilbales
#Q1

# Rois expected value of playing the game is 0$.

#for every first dice rolled by roi he has a 33.33% chance of winning as two out of six options would make him win
# with the second dice:

# first dice = {1,2,3,4,5,6}
# second dice to win = {(2,5),(1,4),(3,6),(2,5),(1,4),(3,6)}

# we can therefor say that every game roi wins he statistaclly will lose 2 games after.

# meaning in money terms he will gain 6$ then losse 3$ and losse 3$ again statistcily as the game continues bringing him to 
# a break even expected value or 0$

# %%
#Q2

#Alex's expected value of playing marker mix up is -2.4$ per game.

#lets break down the possibilitys of winning , breaking even and lossing.

# Winning : alex can win in the follwing situation's: pulls a 3 then 10, pulls a 4 then a 10 or 9, pulls a 5 then a 10 ,9 or 8.
# lets add these up: (1/5)**2 + (1/5*2/5) + (1/5*3/5) == 6/25 = 0.24 == 24 % percent chance of winning.

#Loss: alex can lose in the follwing situations:
# pulls a 1, pulls a 2 and then not a 10, pulls a 3 then not a 10 or 9, pulls a 4 then 6,7, pulls a 5 then a 6.

# lets add these up: 1/5* (1 + 4/5 + 3/5 + 2/5 +1/5) == 3/5 == 0.6 == 60% chance of lossing.

#Draw == 100% - percent of winning - percent of lossing == 1 - 0.6 -0.24 == 0.16 == 16%

#lets run 100 games and see what the results would be:
#wins = 24% = 24 wins
#losses = 60% = 60 losses
#draws =16% = 16 losses

#lets add the value he would gain lose to each game:
#Wins = 5$ = 24*5$ = +120$
#Losses = -6$ = 60*-6$ = -360$
#Draws = 0$ = 16*0$ = 0$

#meaing Alex would after 100 games be at 120$ - 360$ == -240$
#lets divide that over 100 games: -240$/100 == -2.4$ lose per game

# %%
#Q3
#A division of a company has 200 employees, 40%, percent of which are male. Each month,
#the company randomly selects 8 of these employees to have lunch with the CEO

#Answer:

#200 employees 40% men:

# this means 80 men 160 women

# this means on average 8 * 0.4 == 3.2 men are randomly selected to have lunch with the CEO

# SD = ((|8 - 3.2|)/200)**0.5 == 0.3394

# %%
#Q4

#Different dealers may sell the same car for different prices. The sale prices for a particular
#car are normally distributed with a mean and standard deviation of 26,000$ and 2,000$,
#respectively. Suppose we select one of these cars at random. Let X = the sale price (in
#thousands of dollars) for the selected car.

#Find P(26<X<30)

#Answer:
#by the law of 65%, 95% ,99% and the average price of 26,000$
# mu = 26,000$ , 2mu = 28,000$, 3mu = 30,000$

# We can then say from 26,000$ to 28,000$ is around 32.5% and from 28,000$ to 30,000$ is around 15%

# therefor X = 47.5%

# %%
#Q5

#the average mean is 2.5 there for x< 2.5 this would be 2.5* 0.4 /2 == 0.5. this makes sense as tis would be 50% of the distrubution

# 3 - 2.5 = 0.5

#0.5*0.4/2 == 0.1 this is the remading distribution for x < 3

# therefor x<3 = 0.1 + 0.5 == 0.6

# %%
#Q6

#A company has 500 employees, and 60% of them have children. Suppose that we randomly
#select 4 of these employees.
#What is the probability that exactly 3 of the 4 employees selected have children?

#Answer:

#500 emploees, 60% have kids.

# We shall mark with X has kids and 0 no kids:

# these are the following senerios to saticfiy our qestion:

#1 XXX0
#2 0XXX
#3 X0XX
#4 XX0X

#in terms of probability this would be:

#1 0.6*0.6*0.6*0.4
#2 0.4*0.6*0.6*0.6*0
#3 0.6*0.4*0.6*0.6
#4 0.6*0.6*0.4*0.6*0

#We can say then the sum of these possibilitys is: 4*(0.6**3*0.4) == 0.3456 == 34.56% chance

# %%
 #Q7
    
 #Answer:
 # X = 0
    
# we can expect over time for mostly x = 5 or -5 and they will cancel each other out
# some cases 10 or - 10 and they will cancel eachother out
